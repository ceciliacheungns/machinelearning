# %%
import pandas as pd

from bs4 import BeautifulSoup
import requests
import re
import unicodedata

from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import parallel_coordinates

# %matplotlib inline

# %% [markdown]
# #### 2. Explain in detail the code below. In order to better understand the code, you may want to look at the following websites: ####

# %% [markdown]
# - https://www.crummy.com/software/BeautifulSoup/
# - http://www.aivosto.com/vbtips/regex.html
# - https://docs.python.org/2/library/re.html

# %%
# Q2 and Q3

# Attributes to scrape
attributes=['Crossing','Finishing','Heading Accuracy',
 'Short Passing','Volleys','Dribbling','Curve',
 'Free Kick Accuracy','Long Passing','Ball Control','Acceleration',
 'Sprint Speed','Agility','Reactions','Balance',
 'Shot Power','Jumping','Stamina','Strength',
 'Long Shots','Aggression','Interceptions','Positioning',
 'Vision','Penalties','Composure','Marking',
 'Standing Tackle','Sliding Tackle','GK Diving',
 'GK Handling','GK Kicking','GK Positioning','GK Reflexes']
 
links=[]   # links containing the player pages to get
# Q3: Download first 500
#for offset in ['0','100','200', '300', '400']:
for offset in ['0','100','200']:
    #page=requests.get('http://sofifa.com/players?na=14&offset='+offset) # 14 is for England team
    page=requests.get('http://sofifa.com/players?na=52&offset='+offset) # 52 is for Argentina team
    soup=BeautifulSoup(page.content,'html.parser')
    for link in soup.find_all('a'):
        links.append(link.get('href'))
links=['http://sofifa.com'+l for l in links if 'player/'in l]  # Get all the URL links to players' pages

#pattern regular expression 
pattern=r"""\s*([\w\s]*)"""   #file starts with empty spaces... players name...-other stuff
pattern += r""".*\d*\)\s*?([\w\s]*)Age""" # New addition: extraction of positions
for attr in attributes:
    pattern+=r""".*?(\d*\s*"""+attr+r""")"""  #for each attribute we have other stuff..number..attribute..other stuff
pat=re.compile(pattern, re.DOTALL)    #parsing multiline text

rows=[]
for j, link in enumerate(links):
    print(j, link) # Print the index and URL link
    row=[link] # URL link to player's page
    playerpage=requests.get(link) # Get the player's page content and parse into HTML parser
    playersoup=BeautifulSoup(playerpage.content,'html.parser')
    text=playersoup.get_text()
    text=unicodedata.normalize('NFKD', text).encode('ascii','ignore') # Unicode normalise and encode using ASCII
    a=pat.match(text.decode('ascii')) # Match all the fields specified in the regular expressions
    row.append(a.group(1)) # Player's Name
    row.append(a.group(2).strip()) # New Addition: Position Info
    for i in range(3,len(attributes)+3): # The attributes of the players
        row.append(int(a.group(i).split()[0]))
    rows.append(row) # Append all the information of this player
    print(row[1]) # Print Player Name
df=pd.DataFrame(rows,columns=['link','name','position']+attributes) # Initialise Panda Dataframe
#df.to_csv('EnglishPlayers.csv',index=False) # Write to EnglishPlayers.csv
df.to_csv('ArgentinaPlayers.csv',index=False) # Write to ArgentinaPlayers.csv
# Out:
# 0 http://sofifa.com/player/158023
# Lionel Messi
# 1 http://sofifa.com/player/167664
# Gonzalo Higuain
# 2 http://sofifa.com/player/153079
# Sergio Aguero
# 3 http://sofifa.com/player/183898
# Angel Di Maria
# 4 http://sofifa.com/player/211110
# Paulo Dybala
# 5 http://sofifa.com/player/184144
# Nicolas Gaitan
# 6 http://sofifa.com/player/192366
# Nicolas Otamendi
# 7 http://sofifa.com/player/178562
# Ever Banega
# 8 http://sofifa.com/player/142754
# Javier Mascherano
# 9 http://sofifa.com/player/201399
# Mauro Icardi
# 10 http://sofifa.com/player/191180
# Javier Pastore
# 11 http://sofifa.com/player/215316
# Geronimo Rulli
# 12 http://sofifa.com/player/201862
# Marcos Rojo
# 13 http://sofifa.com/player/186547
# Mateo Musacchio
# 14 http://sofifa.com/player/142780
# Gonzalo Rodriguez
# 15 http://sofifa.com/player/170481
# Ezequiel Garay
# 16 http://sofifa.com/player/142784
# Pablo Zabaleta
# 17 http://sofifa.com/player/158963
# Lucas Biglia
# 18 http://sofifa.com/player/176915
# Augusto Fernandez
# 19 http://sofifa.com/player/193061
# Roberto Pereyra
# 20 http://sofifa.com/player/170368
# Erik Lamela
# 21 http://sofifa.com/player/143076
# Alejandro Gomez
# 22 http://sofifa.com/player/183893
# Claudio Yacob
# 23 http://sofifa.com/player/183900
# Diego Perotti
# 24 http://sofifa.com/player/179847
# Federico Fazio
# 25 http://sofifa.com/player/165536
# Gustavo Cabral
# 26 http://sofifa.com/player/143587
# Fernando Belluschi
# 27 http://sofifa.com/player/173306
# Cristian Ansaldi
# 28 http://sofifa.com/player/190972
# Eduardo Salvio
# 29 http://sofifa.com/player/201988
# Federico Fernandez
# 30 http://sofifa.com/player/215051
# Lisandro Lopez
# 31 http://sofifa.com/player/188988
# Manuel Lanzini
# 32 http://sofifa.com/player/173373
# Sergio Romero
# 33 http://sofifa.com/player/207441
# Luciano Vietto
# 34 http://sofifa.com/player/153179
# Pablo Batalla
# 35 http://sofifa.com/player/142707
# Lisandro Lopez
# 36 http://sofifa.com/player/165501
# Nicolas Pareja
# 37 http://sofifa.com/player/142721
# Marcelo Barovero
# 38 http://sofifa.com/player/152999
# Rodrigo Palacio
# 39 http://sofifa.com/player/214997
# Angel Correa
# 40 http://sofifa.com/player/176376
# Ignacio Piatti
# 41 http://sofifa.com/player/215054
# Victor Cuesta
# 42 http://sofifa.com/player/143121
# Jose Sosa
# 43 http://sofifa.com/player/176919
# Nahuel Guzman
# 44 http://sofifa.com/player/139062
# Willy Caballero
# 45 http://sofifa.com/player/215353
# Lucas Alario
# 46 http://sofifa.com/player/134979
# Martin Demichelis
# 47 http://sofifa.com/player/207939
# Guido Pizarro
# 48 http://sofifa.com/player/224334
# Marcos Acuna
# 49 http://sofifa.com/player/196432
# Enzo Perez
# 50 http://sofifa.com/player/172114
# Diego Valeri
# 51 http://sofifa.com/player/183899
# Pablo Piatti
# 52 http://sofifa.com/player/205408
# Santiago Gentiletti
# 53 http://sofifa.com/player/216692
# Sebastian Torrico
# 54 http://sofifa.com/player/201095
# Agustin Marchesin
# 55 http://sofifa.com/player/165560
# Marco Ruben
# 56 http://sofifa.com/player/170719
# Diego Buonanotte
# 57 http://sofifa.com/player/160741
# David Abraham
# 58 http://sofifa.com/player/198140
# Rogelio Funes Mori
# 59 http://sofifa.com/player/200197
# Nicolas Blandi
# 60 http://sofifa.com/player/210950
# Pablo De Blasis
# 61 http://sofifa.com/player/215061
# Dario Benedetto
# 62 http://sofifa.com/player/188955
# Gustavo Bou
# 63 http://sofifa.com/player/139038
# Nicolas Burdisso
# 64 http://sofifa.com/player/173857
# Mariano Andujar
# 65 http://sofifa.com/player/215079
# Pablo Perez
# 66 http://sofifa.com/player/214584
# Franco Armani
# 67 http://sofifa.com/player/205633
# Lucas Castro
# 68 http://sofifa.com/player/193601
# German Pezzella
# 69 http://sofifa.com/player/207439
# Leandro Paredes
# 70 http://sofifa.com/player/223061
# Franco Cervi
# 71 http://sofifa.com/player/153177
# Mauro Zarate
# 72 http://sofifa.com/player/210787
# Mauro Dos Santos
# 73 http://sofifa.com/player/188268
# Lautaro Acosta
# 74 http://sofifa.com/player/190577
# Sebastian Blanco
# 75 http://sofifa.com/player/138123
# Esteban Cambiasso
# 76 http://sofifa.com/player/215181
# Gino Peruzzi
# 77 http://sofifa.com/player/165517
# Fernando Gago
# 78 http://sofifa.com/player/161938
# Mauro Boselli
# 79 http://sofifa.com/player/165531
# Ismael Sosa
# 80 http://sofifa.com/player/210333
# Alexander Szymanowski
# 81 http://sofifa.com/player/183966
# Facundo Roncaglia
# 82 http://sofifa.com/player/214955
# Emmanuel Mas
# 83 http://sofifa.com/player/142775
# Agustin Orion
# 84 http://sofifa.com/player/214977
# Matias Kranevitter
# 85 http://sofifa.com/player/143068
# Matias Delgado
# 86 http://sofifa.com/player/189153
# Mauro Diaz
# 87 http://sofifa.com/player/173030
# Oscar Trejo
# 88 http://sofifa.com/player/172018
# Jonatan Maidana
# 89 http://sofifa.com/player/199667
# Ramiro Funes Mori
# 90 http://sofifa.com/player/219391
# Gonzalo Escalante
# 91 http://sofifa.com/player/215042
# Gaston Lezcano
# 92 http://sofifa.com/player/204555
# Ricardo Alvarez
# 93 http://sofifa.com/player/204050
# Santiago Vergini
# 94 http://sofifa.com/player/211489
# Jonathan Gomez
# 95 http://sofifa.com/player/186405
# Franco Di Santo
# 96 http://sofifa.com/player/139064
# Leonardo Ponzio
# 97 http://sofifa.com/player/211256
# Nicolas Tagliafico
# 98 http://sofifa.com/player/138810
# Alejandro Dominguez
# 99 http://sofifa.com/player/212541
# Leonel Vangioni
# 100 http://sofifa.com/player/219455
# Jonathan Calleri
# 101 http://sofifa.com/player/205632
# Lucas Ocampos
# 102 http://sofifa.com/player/213582
# Alan Ruiz
# 103 http://sofifa.com/player/152916
# Rubens Sambueza
# 104 http://sofifa.com/player/183892
# Gabriel Mercado
# 105 http://sofifa.com/player/142959
# Mariano Barbosa
# 106 http://sofifa.com/player/190576
# Matias Caruzzo
# 107 http://sofifa.com/player/165490
# Mariano Izco
# 108 http://sofifa.com/player/215985
# Fernando Monetti
# 109 http://sofifa.com/player/215254
# Luciano Lollo
# 110 http://sofifa.com/player/215259
# Emiliano Rigoni
# 111 http://sofifa.com/player/208607
# Martin Mantovani
# 112 http://sofifa.com/player/219626
# Jose Luis Gomez
# 113 http://sofifa.com/player/158956
# Julio Alberto Barroso
# 114 http://sofifa.com/player/179696
# Emiliano Insua
# 115 http://sofifa.com/player/167669
# Federico Higuain
# 116 http://sofifa.com/player/214781
# Silvio Romero
# 117 http://sofifa.com/player/215057
# Ivan Marcone
# 118 http://sofifa.com/player/204819
# Emiliano Sala
# 119 http://sofifa.com/player/146963
# Javier Pinola
# 120 http://sofifa.com/player/215321
# Jonathan Schunke
# 121 http://sofifa.com/player/215071
# Milton Casco
# 122 http://sofifa.com/player/110381
# Maximiliano Rodriguez
# 123 http://sofifa.com/player/138798
# German Lux
# 124 http://sofifa.com/player/138806
# Maximiliano Lopez
# 125 http://sofifa.com/player/171830
# Nicolas Spolli
# 126 http://sofifa.com/player/14907
# Albano Bizzarri
# 127 http://sofifa.com/player/172100
# Gabriel Penalba
# 128 http://sofifa.com/player/200278
# Santiago Garcia
# 129 http://sofifa.com/player/153175
# Juan Martinez
# 130 http://sofifa.com/player/142950
# Roman Martinez
# 131 http://sofifa.com/player/188791
# Alberto Costa
# 132 http://sofifa.com/player/186745
# Matias Perez Garcia
# 133 http://sofifa.com/player/216706
# Franco Mussis
# 134 http://sofifa.com/player/219525
# Ezequiel Cerutti
# 135 http://sofifa.com/player/162951
# Marcos Angeleri
# 136 http://sofifa.com/player/188042
# Matias Suarez
# 137 http://sofifa.com/player/152993
# Renato Civelli
# 138 http://sofifa.com/player/213432
# Facundo Ferreyra
# 139 http://sofifa.com/player/219576
# Rodrigo Battaglia
# 140 http://sofifa.com/player/142781
# Leandro Romagnoli
# 141 http://sofifa.com/player/221125
# Sebastian Driussi
# 142 http://sofifa.com/player/216796
# Federico Cartabia
# 143 http://sofifa.com/player/153060
# Juan Insaurralde
# 144 http://sofifa.com/player/215270
# Lucas Zelarayan
# 145 http://sofifa.com/player/214763
# Paolo Goltz
# 146 http://sofifa.com/player/214766
# Carlos Izquierdoz
# 147 http://sofifa.com/player/167666
# Juan Pablo Carrizo
# 148 http://sofifa.com/player/224254
# Cristian Pavon
# 149 http://sofifa.com/player/191488
# Lucas Orban
# 150 http://sofifa.com/player/215053
# Matias Zaldivia
# 151 http://sofifa.com/player/215064
# Julio Furch
# 152 http://sofifa.com/player/186650
# Matias Alustiza
# 153 http://sofifa.com/player/215330
# Joaquin Correa
# 154 http://sofifa.com/player/215331
# Leonardo Jara
# 155 http://sofifa.com/player/188197
# Lucas Viatri
# 156 http://sofifa.com/player/215334
# Guido Carrillo
# 157 http://sofifa.com/player/172077
# Jose Maria Basanta
# 158 http://sofifa.com/player/214594
# Matias Laba
# 159 http://sofifa.com/player/211267
# Ricardo Centurion
# 160 http://sofifa.com/player/211269
# Guillermo Fernandez
# 161 http://sofifa.com/player/226377
# Gonzalo Martinez
# 162 http://sofifa.com/player/158540
# Cristian Campestrini
# 163 http://sofifa.com/player/152912
# Jose Sand
# 164 http://sofifa.com/player/142677
# Leandro Desabato
# 165 http://sofifa.com/player/142938
# German Denis
# 166 http://sofifa.com/player/48745
# Fabricio Coloccini
# 167 http://sofifa.com/player/217201
# Enrique Triverio
# 168 http://sofifa.com/player/212616
# Rodrigo De Paul
# 169 http://sofifa.com/player/214409
# Ezequiel Videla
# 170 http://sofifa.com/player/203671
# Juan Ignacio Gomez
# 171 http://sofifa.com/player/165788
# Leonardo Ulloa
# 172 http://sofifa.com/player/215199
# Ruben Botta
# 173 http://sofifa.com/player/183969
# Juan Forlin
# 174 http://sofifa.com/player/215212
# Guillermo Sara
# 175 http://sofifa.com/player/226226
# Giovani Lo Celso
# 176 http://sofifa.com/player/213433
# Fernando Tobio
# 177 http://sofifa.com/player/214973
# Lucas Villafanez
# 178 http://sofifa.com/player/215998
# Ignacio Fernandez
# 179 http://sofifa.com/player/198347
# Franco Jara
# 180 http://sofifa.com/player/200653
# Guillermo Burdisso
# 181 http://sofifa.com/player/185061
# Javier Morales
# 182 http://sofifa.com/player/167661
# Jesus Mendez
# 183 http://sofifa.com/player/143598
# Luciano Pocrnjic
# 184 http://sofifa.com/player/216816
# Giovanni Simeone
# 185 http://sofifa.com/player/140274
# Daniel Diaz
# 186 http://sofifa.com/player/214770
# Diego Gonzalez
# 187 http://sofifa.com/player/173300
# Sebastian Leto
# 188 http://sofifa.com/player/215049
# Damian Perez
# 189 http://sofifa.com/player/223247
# Nelson Acevedo
# 190 http://sofifa.com/player/223248
# Juan Martin Lucero
# 191 http://sofifa.com/player/212506
# Mauro Matos
# 192 http://sofifa.com/player/215069
# Rodrigo Rey
# 193 http://sofifa.com/player/221219
# German Conti
# 194 http://sofifa.com/player/157219
# Gaston Fernandez
# 195 http://sofifa.com/player/188196
# Ricardo Noir
# 196 http://sofifa.com/player/189228
# Maximiliano Caire
# 197 http://sofifa.com/player/215089
# Enzo Kalinski
# 198 http://sofifa.com/player/171828
# Ignacio Scocco
# 199 http://sofifa.com/player/205630
# Luciano Abecasis
# 200 http://sofifa.com/player/186695
# Ezequiel Munoz
# 201 http://sofifa.com/player/206152
# Luciano Aued
# 202 http://sofifa.com/player/206154
# Hector Canteros
# 203 http://sofifa.com/player/226379
# Marcos Diaz
# 204 http://sofifa.com/player/142670
# Rodrigo Brana
# 205 http://sofifa.com/player/142942
# Javier Gandolfi
# 206 http://sofifa.com/player/203872
# Gabriel Hauche
# 207 http://sofifa.com/player/215144
# Emanuel Insua
# 208 http://sofifa.com/player/221551
# Emanuel Mammana
# 209 http://sofifa.com/player/226419
# Fabian Sambueza
# 210 http://sofifa.com/player/162932
# Pablo Barrientos
# 211 http://sofifa.com/player/192373
# Milton Caraglio
# 212 http://sofifa.com/player/223099
# Diego Churin
# 213 http://sofifa.com/player/216700
# Maximiliano Meza
# 214 http://sofifa.com/player/191104
# Juan Mercier
# 215 http://sofifa.com/player/178566
# Javier Garcia
# 216 http://sofifa.com/player/165787
# Jorge Ortiz
# 217 http://sofifa.com/player/215202
# Lucas Janson
# 218 http://sofifa.com/player/190629
# Daniel Villalva
# 219 http://sofifa.com/player/206005
# Denis Stracqualursi
# 220 http://sofifa.com/player/221627
# Hernan Hechalar
# 221 http://sofifa.com/player/220609
# Valentin Vada
# 222 http://sofifa.com/player/189889
# Ezequiel Luna
# 223 http://sofifa.com/player/214987
# German Voboril
# 224 http://sofifa.com/player/142800
# Maximiliano Velazquez
# 225 http://sofifa.com/player/216019
# Damian Musto
# 226 http://sofifa.com/player/231128
# Hernan Toledo
# 227 http://sofifa.com/player/222429
# Andres Cubas
# 228 http://sofifa.com/player/201953
# Juan Sanchez Mino
# 229 http://sofifa.com/player/216033
# Jorge Broun
# 230 http://sofifa.com/player/167665
# Nicolas Domingo
# 231 http://sofifa.com/player/198386
# Sebastian Dubarbier
# 232 http://sofifa.com/player/216055
# Federico Carrizo
# 233 http://sofifa.com/player/213253
# Hernan Grana
# 234 http://sofifa.com/player/215050
# Diego Braghieri
# 235 http://sofifa.com/player/167435
# Oscar Ustari
# 236 http://sofifa.com/player/143119
# Mariano Pavone
# 237 http://sofifa.com/player/215059
# Martin Rolle
# 238 http://sofifa.com/player/215322
# Jonathan Silva
# 239 http://sofifa.com/player/220715
# Ezequiel Ponce
# 240 http://sofifa.com/player/204337
# Gervasio Nunez
# 241 http://sofifa.com/player/139058
# Omar Perez
# 242 http://sofifa.com/player/184626
# Nicolas Sanchez
# 243 http://sofifa.com/player/49212
# Julian Speroni
# 244 http://sofifa.com/player/215358
# Marcelo Meli
# 245 http://sofifa.com/player/234816
# Nicolas Gorosito
# 246 http://sofifa.com/player/158790
# Luis Gonzalo Bustamante
# 247 http://sofifa.com/player/215111
# Gonzalo Veron
# 248 http://sofifa.com/player/153164
# Alejandro Faurlin
# 249 http://sofifa.com/player/226385
# Cristian Omar Espinoza
# 250 http://sofifa.com/player/172113
# Matias Fritzler
# 251 http://sofifa.com/player/202069
# Jose Luis Fernandez
# 252 http://sofifa.com/player/210788
# Nicolas Martinez
# 253 http://sofifa.com/player/184422
# Luis Ardente
# 254 http://sofifa.com/player/210281
# Cristian Pellerano
# 255 http://sofifa.com/player/224367
# German Lanaro
# 256 http://sofifa.com/player/192370
# Mauro Formica
# 257 http://sofifa.com/player/192371
# Fabian Rinaudo
# 258 http://sofifa.com/player/229749
# Alexander Barboza
# 259 http://sofifa.com/player/193141
# Ivan Pillud
# 260 http://sofifa.com/player/225659
# Guido Rodriguez
# 261 http://sofifa.com/player/158088
# Pablo Alvarez
# 262 http://sofifa.com/player/215177
# Francisco Cerro
# 263 http://sofifa.com/player/214671
# Rodrigo Gomez
# 264 http://sofifa.com/player/219553
# Claudio Aquino
# 265 http://sofifa.com/player/152997
# Dario Cvitanich
# 266 http://sofifa.com/player/142762
# Jonathan Bottinelli
# 267 http://sofifa.com/player/214965
# Claudio Riano
# 268 http://sofifa.com/player/143032
# Ismael Blanco
# 269 http://sofifa.com/player/165561
# Cristian Villagra
# 270 http://sofifa.com/player/173245
# Ramon Fernandez
# 271 http://sofifa.com/player/219841
# Jorge Figal
# 272 http://sofifa.com/player/171975
# Gonzalo Bergessio
# 273 http://sofifa.com/player/214989
# Martin Benitez
# 274 http://sofifa.com/player/224461
# Walter Montoya
# 275 http://sofifa.com/player/214993
# Pablo Alvarado
# 276 http://sofifa.com/player/123603
# Hugo Campagnaro
# 277 http://sofifa.com/player/199387
# Pablo Chavarria
# 278 http://sofifa.com/player/220128
# Jonatan Cristaldo
# 279 http://sofifa.com/player/215266
# Lucas Melano
# 280 http://sofifa.com/player/216036
# Rafael Delgado
# 281 http://sofifa.com/player/193510
# Diego Novaretti
# 282 http://sofifa.com/player/219879
# Matias Pisano
# 283 http://sofifa.com/player/153066
# Lucas Licht
# 284 http://sofifa.com/player/218621
# Facundo Sanchez
# 285 http://sofifa.com/player/143102
# Diego Colotto
# 286 http://sofifa.com/player/142592
# Israel Damonte
# 287 http://sofifa.com/player/215309
# Lucas Albertengo
# 288 http://sofifa.com/player/223245
# Brian Fernandez
# 289 http://sofifa.com/player/219167
# Sergio Vittor
# 290 http://sofifa.com/player/159520
# Nereo Fernandez
# 291 http://sofifa.com/player/215332
# Carlos Auzqui
# 292 http://sofifa.com/player/207657
# Fernando Barrientos
# 293 http://sofifa.com/player/199726
# Marco Torsiglieri
# 294 http://sofifa.com/player/232244
# Santiago Ascacibar
# 295 http://sofifa.com/player/225591
# Leonardo Suarez
# 296 http://sofifa.com/player/224057
# Agustin Farias
# 297 http://sofifa.com/player/207679
# Facundo Pereyra
# 298 http://sofifa.com/player/211265
# Ariel Rojas
# 299 http://sofifa.com/player/218433
# Federico Vega

# %% [markdown]
# The python script to extract player's informations is split into three main parts. One part that accesses the website and downloads links for each player, one part that creates the regular expression that matches a desired pattern, and the final part that combines both parts to extract the data.
#
# - attribute list: attributes to be extracted from a player's stats
# - links list: stores all the extracted page links for each player
# - inside for loop
#     - the for loop loops through list ['0','100','200'] and adds each number to the url. Since each page displays 100 players we need to go to 200. The "requests.get" function creates a request object for each page
#     - each page's content (html code) is downloaded and restored to readable html format by the "BeautifulSoup" function with the argument "html.parser"
#     - the "find_all" function of the BeautifulSoup object is used to the content between tag "a"
#     - the "href" tag is used to locate and extract all the links to websites in the downloaded html code
#     - list comprehension to extract all the links that include "player/"
# - create pattern for regular expression using the list of attributes created at the top
#
# - loop thourhg the links extracted in the first part
#     - does the same procedure as in the first step but with each players link
#     - uses the regular expression to extract the player stats
#     - uses another for loop to extract each matched item and saves it to a list
#     - makes a dataframe out of the list and saves the file

# %% [markdown]
# #### 3. How would you change the code to download the first 500 English players instead?

# %% [markdown]
# In order to change the above code to download the first 500 English players we need to make the following alternations:
#
# - extend the first for loop by '300' and '400' in order to get the first 500 and not 300 players
# - change the url in the first loop to the one for English players
# - change the filename the downloaded data is saved to
#
# All the changes are marked with "###" in the code below.

# %%
attributes=['Crossing','Finishing','Heading Accuracy',
 'Short Passing','Volleys','Dribbling','Curve',
 'Free Kick Accuracy','Long Passing','Ball Control','Acceleration',
 'Sprint Speed','Agility','Reactions','Balance',
 'Shot Power','Jumping','Stamina','Strength',
 'Long Shots','Aggression','Interceptions','Positioning',
 'Vision','Penalties','Composure','Marking',
 'Standing Tackle','Sliding Tackle','GK Diving',
 'GK Handling','GK Kicking','GK Positioning','GK Reflexes']
 
links=[]
for offset in ['0','100','200', '300', '400']: # Get First 500 English Players
    page=requests.get('http://sofifa.com/players?na=14&offset='+offset) # 14 is for England team
    soup=BeautifulSoup(page.content,'html.parser')
    for link in soup.find_all('a'):
        links.append(link.get('href'))
links=['http://sofifa.com'+l for l in links if 'player/'in l]

pattern=r"""\s*([\w\s]*)"""
pattern += r""".*\d*\)\s*?([\w\s]*)Age"""
for attr in attributes:
    pattern+=r""".*?(\d*\s*"""+attr+r""")"""
pat=re.compile(pattern, re.DOTALL)

rows=[]
for j, link in enumerate(links):
    print(j, link)
    row=[link]
    playerpage=requests.get(link)
    playersoup=BeautifulSoup(playerpage.content,'html.parser')
    text=playersoup.get_text()
    text=unicodedata.normalize('NFKD', text).encode('ascii','ignore')
    a=pat.match(text.decode('ascii'))
    row.append(a.group(1))
    row.append(a.group(2).strip())
    for i in range(3,len(attributes)+3):
        row.append(int(a.group(i).split()[0]))
    rows.append(row)
    print(row[1])
df=pd.DataFrame(rows,columns=['link','name','position']+attributes)
df.to_csv('EnglishPlayers.csv',index=False) # Write to EnglishPlayers.csv
# Out:
# 0 http://sofifa.com/player/202126
# Harry Kane
# 1 http://sofifa.com/player/150724
# Joe Hart
# 2 http://sofifa.com/player/54050
# Wayne Rooney
# 3 http://sofifa.com/player/163631
# Leighton Baines
# 4 http://sofifa.com/player/171833
# Daniel Sturridge
# 5 http://sofifa.com/player/180819
# Adam Lallana
# 6 http://sofifa.com/player/164468
# Gary Cahill
# 7 http://sofifa.com/player/202652
# Raheem Sterling
# 8 http://sofifa.com/player/189881
# Chris Smalling
# 9 http://sofifa.com/player/189461
# Jack Wilshere
# 10 http://sofifa.com/player/203042
# Jack Butland
# 11 http://sofifa.com/player/183711
# Jordan Henderson
# 12 http://sofifa.com/player/13732
# John Terry
# 13 http://sofifa.com/player/211117
# Dele Alli
# 14 http://sofifa.com/player/188377
# Kyle Walker
# 15 http://sofifa.com/player/190456
# Nathaniel Clyne
# 16 http://sofifa.com/player/199189
# Ross Barkley
# 17 http://sofifa.com/player/50542
# Jermain Defoe
# 18 http://sofifa.com/player/169595
# Danny Rose
# 19 http://sofifa.com/player/169596
# Ryan Shawcross
# 20 http://sofifa.com/player/21146
# Michael Carrick
# 21 http://sofifa.com/player/53914
# Phil Jagielka
# 22 http://sofifa.com/player/164859
# Theo Walcott
# 23 http://sofifa.com/player/186132
# Danny Drinkwater
# 24 http://sofifa.com/player/186146
# Danny Welbeck
# 25 http://sofifa.com/player/163155
# Ben Foster
# 26 http://sofifa.com/player/194957
# Phil Jones
# 27 http://sofifa.com/player/205988
# Luke Shaw
# 28 http://sofifa.com/player/6826
# Gareth Barry
# 29 http://sofifa.com/player/138412
# James Milner
# 30 http://sofifa.com/player/208830
# Jamie Vardy
# 31 http://sofifa.com/player/186115
# Kieran Gibbs
# 32 http://sofifa.com/player/152908
# Ashley Young
# 33 http://sofifa.com/player/202335
# Eric Dier
# 34 http://sofifa.com/player/198784
# Alex Oxlade
# 35 http://sofifa.com/player/172203
# Fraser Forster
# 36 http://sofifa.com/player/157665
# Scott Dann
# 37 http://sofifa.com/player/169705
# Ryan Bertrand
# 38 http://sofifa.com/player/152879
# Mark Noble
# 39 http://sofifa.com/player/182836
# Andy Carroll
# 40 http://sofifa.com/player/203574
# John Stones
# 41 http://sofifa.com/player/183125
# Troy Deeney
# 42 http://sofifa.com/player/195671
# Charlie Austin
# 43 http://sofifa.com/player/183427
# Fabian Delph
# 44 http://sofifa.com/player/152747
# Aaron Lennon
# 45 http://sofifa.com/player/163264
# Tom Heaton
# 46 http://sofifa.com/player/169706
# Jack Cork
# 47 http://sofifa.com/player/207599
# Michael Keane
# 48 http://sofifa.com/player/190717
# Michail Antonio
# 49 http://sofifa.com/player/195859
# Danny Ings
# 50 http://sofifa.com/player/189725
# Tom Cleverley
# 51 http://sofifa.com/player/137782
# Glen Johnson
# 52 http://sofifa.com/player/169792
# Jay Rodriguez
# 53 http://sofifa.com/player/194932
# Andros Townsend
# 54 http://sofifa.com/player/173436
# Nathan Dyer
# 55 http://sofifa.com/player/140415
# Leon Britton
# 56 http://sofifa.com/player/207494
# Jesse Lingard
# 57 http://sofifa.com/player/169607
# Lee Cattermole
# 58 http://sofifa.com/player/163761
# Curtis Davies
# 59 http://sofifa.com/player/186345
# Kieran Trippier
# 60 http://sofifa.com/player/189165
# Jonjo Shelvey
# 61 http://sofifa.com/player/120312
# Michael Dawson
# 62 http://sofifa.com/player/231677
# Marcus Rashford
# 63 http://sofifa.com/player/204289
# Saido Berahino
# 64 http://sofifa.com/player/205569
# James Ward
# 65 http://sofifa.com/player/54051
# Wayne Routledge
# 66 http://sofifa.com/player/183130
# Marc Albrighton
# 67 http://sofifa.com/player/194138
# Andre Gray
# 68 http://sofifa.com/player/196978
# Callum Wilson
# 69 http://sofifa.com/player/204935
# Jordan Pickford
# 70 http://sofifa.com/player/189324
# Alex McCarthy
# 71 http://sofifa.com/player/189615
# Aaron Cresswell
# 72 http://sofifa.com/player/152514
# Jason Puncheon
# 73 http://sofifa.com/player/173546
# James Tomkins
# 74 http://sofifa.com/player/169214
# Scott Sinclair
# 75 http://sofifa.com/player/54033
# Tom Huddlestone
# 76 http://sofifa.com/player/186392
# Joel Ward
# 77 http://sofifa.com/player/178487
# Craig Gardner
# 78 http://sofifa.com/player/51257
# Peter Crouch
# 79 http://sofifa.com/player/198719
# Nathan Redmond
# 80 http://sofifa.com/player/205670
# Dwight Gayle
# 81 http://sofifa.com/player/164464
# Bradley Wright
# 82 http://sofifa.com/player/169600
# Danny Simpson
# 83 http://sofifa.com/player/189059
# Jake Livermore
# 84 http://sofifa.com/player/193942
# Jack Colback
# 85 http://sofifa.com/player/205989
# Calum Chambers
# 86 http://sofifa.com/player/183465
# Jack Rodwell
# 87 http://sofifa.com/player/206516
# Will Hughes
# 88 http://sofifa.com/player/201155
# Ravel Morrison
# 89 http://sofifa.com/player/199633
# Matthew Lowton
# 90 http://sofifa.com/player/138193
# Joey Barton
# 91 http://sofifa.com/player/190683
# Ryan Mason
# 92 http://sofifa.com/player/172768
# Andrew Surman
# 93 http://sofifa.com/player/193504
# Steven Caulker
# 94 http://sofifa.com/player/186598
# Kyle Naughton
# 95 http://sofifa.com/player/199915
# Lewis Dunk
# 96 http://sofifa.com/player/193011
# Steve Cook
# 97 http://sofifa.com/player/54013
# Stewart Downing
# 98 http://sofifa.com/player/186385
# Adam Clayton
# 99 http://sofifa.com/player/211504
# Lewis Baker
# 100 http://sofifa.com/player/200758
# Liam Moore
# 101 http://sofifa.com/player/202052
# Benik Afobe
# 102 http://sofifa.com/player/123463
# Jermaine Pennant
# 103 http://sofifa.com/player/200521
# Tom Ince
# 104 http://sofifa.com/player/164462
# Nedum Onuoha
# 105 http://sofifa.com/player/191089
# Connor Wickham
# 106 http://sofifa.com/player/179574
# Gary Hooper
# 107 http://sofifa.com/player/183422
# Jonny Howson
# 108 http://sofifa.com/player/172937
# Glenn Murray
# 109 http://sofifa.com/player/169638
# Charlie Daniels
# 110 http://sofifa.com/player/182184
# Dale Stephens
# 111 http://sofifa.com/player/135883
# Simon Francis
# 112 http://sofifa.com/player/189682
# Ben Mee
# 113 http://sofifa.com/player/101880
# Rob Green
# 114 http://sofifa.com/player/169721
# Micah Richards
# 115 http://sofifa.com/player/186116
# Henri Lansbury
# 116 http://sofifa.com/player/188168
# George Friend
# 117 http://sofifa.com/player/163600
# John Ruddy
# 118 http://sofifa.com/player/34079
# Ashley Cole
# 119 http://sofifa.com/player/193569
# Tom Lees
# 120 http://sofifa.com/player/160292
# Ben Watson
# 121 http://sofifa.com/player/205351
# Alex Pritchard
# 122 http://sofifa.com/player/186158
# Kyle Bartley
# 123 http://sofifa.com/player/170305
# Cole Skuse
# 124 http://sofifa.com/player/165191
# Cameron Jerome
# 125 http://sofifa.com/player/189280
# Ashley Westwood
# 126 http://sofifa.com/player/139368
# Jason Shackell
# 127 http://sofifa.com/player/157804
# Scott Carson
# 128 http://sofifa.com/player/190852
# Callum McManaman
# 129 http://sofifa.com/player/140422
# Alex Baptiste
# 130 http://sofifa.com/player/200841
# Carl Jenkinson
# 131 http://sofifa.com/player/180635
# Tommy Elphick
# 132 http://sofifa.com/player/184749
# Dan Gosling
# 133 http://sofifa.com/player/182207
# David Stockdale
# 134 http://sofifa.com/player/200408
# Ben Gibson
# 135 http://sofifa.com/player/204760
# Charlie Taylor
# 136 http://sofifa.com/player/184037
# Martin Kelly
# 137 http://sofifa.com/player/169708
# Sam Hutchinson
# 138 http://sofifa.com/player/208892
# Sam Byram
# 139 http://sofifa.com/player/162054
# Mark Bunn
# 140 http://sofifa.com/player/189446
# Junior Stanislas
# 141 http://sofifa.com/player/203783
# Tommy Smith
# 142 http://sofifa.com/player/134941
# Steve Sidwell
# 143 http://sofifa.com/player/139296
# David Nugent
# 144 http://sofifa.com/player/222513
# Rolando Aarons
# 145 http://sofifa.com/player/13879
# Rickie Lambert
# 146 http://sofifa.com/player/171831
# Michael Mancienne
# 147 http://sofifa.com/player/159034
# Steven Taylor
# 148 http://sofifa.com/player/8517
# Scott Parker
# 149 http://sofifa.com/player/162891
# David Jones
# 150 http://sofifa.com/player/172904
# Lee Tomlin
# 151 http://sofifa.com/player/188782
# Michael Morrison
# 152 http://sofifa.com/player/193910
# Adam Forshaw
# 153 http://sofifa.com/player/202113
# Moses Odubajo
# 154 http://sofifa.com/player/183442
# James Henry
# 155 http://sofifa.com/player/193172
# Ben Marshall
# 156 http://sofifa.com/player/152991
# Dean Marney
# 157 http://sofifa.com/player/190885
# Adam Smith
# 158 http://sofifa.com/player/206517
# Jack Grealish
# 159 http://sofifa.com/player/166838
# Marc Pugh
# 160 http://sofifa.com/player/231352
# Tammy Abraham
# 161 http://sofifa.com/player/138181
# Michael Turner
# 162 http://sofifa.com/player/206538
# Kevin Stewart
# 163 http://sofifa.com/player/152536
# Bradley Johnson
# 164 http://sofifa.com/player/220633
# Demarai Gray
# 165 http://sofifa.com/player/203487
# Jamaal Lascelles
# 166 http://sofifa.com/player/198379
# George Thorne
# 167 http://sofifa.com/player/163571
# Matt Jarvis
# 168 http://sofifa.com/player/183546
# Jonathan Hogg
# 169 http://sofifa.com/player/202491
# Tom Carroll
# 170 http://sofifa.com/player/203263
# Harry Maguire
# 171 http://sofifa.com/player/162314
# Peter Whittingham
# 172 http://sofifa.com/player/162315
# Liam Ridgewell
# 173 http://sofifa.com/player/201999
# Jon Flanagan
# 174 http://sofifa.com/player/169498
# Joe Garner
# 175 http://sofifa.com/player/163625
# Grant Leadbitter
# 176 http://sofifa.com/player/170039
# Ryan Shotton
# 177 http://sofifa.com/player/184387
# John Bostock
# 178 http://sofifa.com/player/215374
# Scott Hogan
# 179 http://sofifa.com/player/169586
# Fraizer Campbell
# 180 http://sofifa.com/player/184436
# Alex Smithies
# 181 http://sofifa.com/player/169593
# Kieran Lee
# 182 http://sofifa.com/player/222079
# Josh Onomah
# 183 http://sofifa.com/player/152723
# Liam Rosenior
# 184 http://sofifa.com/player/187033
# Sean Morrison
# 185 http://sofifa.com/player/193182
# Wes Foderingham
# 186 http://sofifa.com/player/19104
# Clint Hill
# 187 http://sofifa.com/player/152741
# Mike Williamson
# 188 http://sofifa.com/player/50598
# Darren Bent
# 189 http://sofifa.com/player/202408
# Aden Flint
# 190 http://sofifa.com/player/201908
# Andre Wisdom
# 191 http://sofifa.com/player/204215
# Adam Reach
# 192 http://sofifa.com/player/182209
# Mark Beevers
# 193 http://sofifa.com/player/212419
# Tyrone Mings
# 194 http://sofifa.com/player/206534
# Patrick Bamford
# 195 http://sofifa.com/player/202695
# James Tarkowski
# 196 http://sofifa.com/player/176841
# Lukas Jutkiewicz
# 197 http://sofifa.com/player/195020
# David Davis
# 198 http://sofifa.com/player/189403
# Nathan Baker
# 199 http://sofifa.com/player/195037
# Danny Batth
# 200 http://sofifa.com/player/183774
# Ryan Bennett
# 201 http://sofifa.com/player/138722
# Billy Jones
# 202 http://sofifa.com/player/205540
# Jordon Ibe
# 203 http://sofifa.com/player/203505
# Joe Bryan
# 204 http://sofifa.com/player/188657
# Declan Rudd
# 205 http://sofifa.com/player/207616
# Adam Webster
# 206 http://sofifa.com/player/156165
# Matthew Mills
# 207 http://sofifa.com/player/186117
# Jordon Mutch
# 208 http://sofifa.com/player/220940
# Cameron Brannagan
# 209 http://sofifa.com/player/167694
# Matthew Connolly
# 210 http://sofifa.com/player/194319
# Danny Ward
# 211 http://sofifa.com/player/221982
# Patrick Roberts
# 212 http://sofifa.com/player/173859
# Sam Baldock
# 213 http://sofifa.com/player/224294
# Lewis Cook
# 214 http://sofifa.com/player/186156
# Luke Ayling
# 215 http://sofifa.com/player/226093
# Che Adams
# 216 http://sofifa.com/player/170286
# Scott Golbourne
# 217 http://sofifa.com/player/173614
# Jason Pearce
# 218 http://sofifa.com/player/204847
# Todd Kane
# 219 http://sofifa.com/player/205360
# Kemar Roofe
# 220 http://sofifa.com/player/152880
# Chris Cohen
# 221 http://sofifa.com/player/211506
# John Swift
# 222 http://sofifa.com/player/193331
# Karl Darlow
# 223 http://sofifa.com/player/211514
# Reece James
# 224 http://sofifa.com/player/192320
# Gary Gardner
# 225 http://sofifa.com/player/163396
# James Vaughan
# 226 http://sofifa.com/player/205897
# Nathaniel Chalobah
# 227 http://sofifa.com/player/225100
# Joe Gomez
# 228 http://sofifa.com/player/18771
# Luke Steele
# 229 http://sofifa.com/player/53593
# Gary O
# 230 http://sofifa.com/player/13914
# Paul Robinson
# 231 http://sofifa.com/player/165219
# Jack Hobbs
# 232 http://sofifa.com/player/169575
# Lee Peltier
# 233 http://sofifa.com/player/183145
# Shaleum Logan
# 234 http://sofifa.com/player/193900
# Jack Hunt
# 235 http://sofifa.com/player/231535
# Cameron Borthwick
# 236 http://sofifa.com/player/169843
# Ben Turner
# 237 http://sofifa.com/player/200820
# Jordan Obita
# 238 http://sofifa.com/player/200309
# Tendayi Darikwa
# 239 http://sofifa.com/player/169078
# Luke Freeman
# 240 http://sofifa.com/player/140423
# Jake Buxton
# 241 http://sofifa.com/player/169609
# Jonathan Grounds
# 242 http://sofifa.com/player/198032
# Dan Burn
# 243 http://sofifa.com/player/183706
# Martyn Waghorn
# 244 http://sofifa.com/player/199580
# Connor Goldson
# 245 http://sofifa.com/player/172960
# Lewis Grabban
# 246 http://sofifa.com/player/193185
# Scott Malone
# 247 http://sofifa.com/player/19874
# Dean Whitehead
# 248 http://sofifa.com/player/140451
# Michael Kightly
# 249 http://sofifa.com/player/189619
# Korey Smith
# 250 http://sofifa.com/player/189885
# Craig Noone
# 251 http://sofifa.com/player/186559
# Jacob Butterfield
# 252 http://sofifa.com/player/222400
# Harry Winks
# 253 http://sofifa.com/player/198350
# Daniel Bentley
# 254 http://sofifa.com/player/173518
# Tom Clarke
# 255 http://sofifa.com/player/204761
# Grant Hall
# 256 http://sofifa.com/player/195036
# Sam Winnall
# 257 http://sofifa.com/player/138726
# Joleon Lescott
# 258 http://sofifa.com/player/172780
# Brett Pitman
# 259 http://sofifa.com/player/184301
# Jay Emmanuel
# 260 http://sofifa.com/player/213490
# Isaiah Brown
# 261 http://sofifa.com/player/206594
# Solly March
# 262 http://sofifa.com/player/225539
# Dominic Solanke
# 263 http://sofifa.com/player/118794
# Andy Lonergan
# 264 http://sofifa.com/player/163340
# Danny Graham
# 265 http://sofifa.com/player/193549
# Shaun Hutchinson
# 266 http://sofifa.com/player/187150
# Will Buckley
# 267 http://sofifa.com/player/205585
# Jack Price
# 268 http://sofifa.com/player/178194
# Dean Cox
# 269 http://sofifa.com/player/172823
# Nicky Maynard
# 270 http://sofifa.com/player/186139
# Matty James
# 271 http://sofifa.com/player/218658
# Dominic Iorfa
# 272 http://sofifa.com/player/190247
# John Brayford
# 273 http://sofifa.com/player/210985
# Ben Osborn
# 274 http://sofifa.com/player/152875
# Johnnie Jackson
# 275 http://sofifa.com/player/194091
# Michael Jacobs
# 276 http://sofifa.com/player/222256
# Teddy Bishop
# 277 http://sofifa.com/player/196916
# Marlon Pack
# 278 http://sofifa.com/player/170818
# Steven Davies
# 279 http://sofifa.com/player/13130
# Wes Brown
# 280 http://sofifa.com/player/189772
# Martyn Woolford
# 281 http://sofifa.com/player/170074
# Mark Davies
# 282 http://sofifa.com/player/156253
# Joe Lewis
# 283 http://sofifa.com/player/189541
# Chris Solly
# 284 http://sofifa.com/player/191079
# Harlee Dean
# 285 http://sofifa.com/player/165736
# David Wheater
# 286 http://sofifa.com/player/199027
# Jack Robinson
# 287 http://sofifa.com/player/164469
# Gabriel Agbonlahor
# 288 http://sofifa.com/player/172928
# Chris Lines
# 289 http://sofifa.com/player/155524
# Richard Stearman
# 290 http://sofifa.com/player/213642
# James Wilson
# 291 http://sofifa.com/player/213905
# Sam Gallagher
# 292 http://sofifa.com/player/208534
# Alfie Mawson
# 293 http://sofifa.com/player/225441
# Kasey Palmer
# 294 http://sofifa.com/player/162979
# Andrew Davies
# 295 http://sofifa.com/player/53412
# Anton Ferdinand
# 296 http://sofifa.com/player/138151
# John Welsh
# 297 http://sofifa.com/player/204464
# Joe Ralls
# 298 http://sofifa.com/player/162993
# James Perch
# 299 http://sofifa.com/player/170163
# Lewis McGugan
# 300 http://sofifa.com/player/100803
# Karl Henry
# 301 http://sofifa.com/player/187077
# Freddie Sears
# 302 http://sofifa.com/player/216268
# Duncan Watmore
# 303 http://sofifa.com/player/222420
# Grant Ward
# 304 http://sofifa.com/player/192473
# Lee Novak
# 305 http://sofifa.com/player/228829
# Marc Roberts
# 306 http://sofifa.com/player/190430
# Joe Bennett
# 307 http://sofifa.com/player/183527
# Jay Spearing
# 308 http://sofifa.com/player/163050
# Billy Sharp
# 309 http://sofifa.com/player/53739
# Lee Grant
# 310 http://sofifa.com/player/163828
# Adam Le Fondre
# 311 http://sofifa.com/player/205818
# Ryan Woods
# 312 http://sofifa.com/player/203265
# Tyler Blackett
# 313 http://sofifa.com/player/156164
# Martin Cranie
# 314 http://sofifa.com/player/206085
# Jacob Murphy
# 315 http://sofifa.com/player/162053
# Luke Chambers
# 316 http://sofifa.com/player/224520
# Ryan Kent
# 317 http://sofifa.com/player/156170
# Jerome Thomas
# 318 http://sofifa.com/player/199960
# Jamie Paterson
# 319 http://sofifa.com/player/220697
# James Maddison
# 320 http://sofifa.com/player/53792
# Mark Hudson
# 321 http://sofifa.com/player/205346
# Ryan Fredericks
# 322 http://sofifa.com/player/206115
# Isaac Hayden
# 323 http://sofifa.com/player/218659
# Matt Targett
# 324 http://sofifa.com/player/50723
# Stuart Taylor
# 325 http://sofifa.com/player/173349
# Lionel Ainsworth
# 326 http://sofifa.com/player/213798
# Alex Mowatt
# 327 http://sofifa.com/player/200746
# John Lundstram
# 328 http://sofifa.com/player/198704
# Josh McEachran
# 329 http://sofifa.com/player/203060
# Josh Vela
# 330 http://sofifa.com/player/189498
# Harry Forrester
# 331 http://sofifa.com/player/193083
# Ross Draper
# 332 http://sofifa.com/player/228668
# Matty Taylor
# 333 http://sofifa.com/player/203069
# Ryan Tunnicliffe
# 334 http://sofifa.com/player/231485
# Axel Tuanzebe
# 335 http://sofifa.com/player/53827
# Matt Taylor
# 336 http://sofifa.com/player/196952
# Jake Bidwell
# 337 http://sofifa.com/player/116314
# David Martin
# 338 http://sofifa.com/player/198235
# Jon Taylor
# 339 http://sofifa.com/player/203355
# Robert Hall
# 340 http://sofifa.com/player/193884
# Sam Clucas
# 341 http://sofifa.com/player/189278
# Luke Murphy
# 342 http://sofifa.com/player/229984
# Ben Chilwell
# 343 http://sofifa.com/player/169568
# Adam Hammill
# 344 http://sofifa.com/player/182883
# Kieran Agard
# 345 http://sofifa.com/player/200292
# Jason Lowe
# 346 http://sofifa.com/player/173671
# Kyle McFadzean
# 347 http://sofifa.com/player/183147
# Seb Hines
# 348 http://sofifa.com/player/231281
# Trent Alexander
# 349 http://sofifa.com/player/204411
# Rohan Ince
# 350 http://sofifa.com/player/189311
# Tom Hateley
# 351 http://sofifa.com/player/177793
# Greg Tansey
# 352 http://sofifa.com/player/211595
# George Evans
# 353 http://sofifa.com/player/156299
# Shaun Barker
# 354 http://sofifa.com/player/179856
# David Perkins
# 355 http://sofifa.com/player/221841
# Adam Armstrong
# 356 http://sofifa.com/player/202131
# Jordan Cousins
# 357 http://sofifa.com/player/216467
# Jack Payne
# 358 http://sofifa.com/player/172179
# Tommy Spurr
# 359 http://sofifa.com/player/161943
# Elliott Ward
# 360 http://sofifa.com/player/195479
# James Tavernier
# 361 http://sofifa.com/player/169112
# Lee Martin
# 362 http://sofifa.com/player/211098
# Bradley Dack
# 363 http://sofifa.com/player/213666
# Ruben Loftus
# 364 http://sofifa.com/player/177315
# Gary Roberts
# 365 http://sofifa.com/player/162980
# Andrew Taylor
# 366 http://sofifa.com/player/205990
# Harrison Reed
# 367 http://sofifa.com/player/138413
# Matthew Kilgallon
# 368 http://sofifa.com/player/213689
# Ben Pearson
# 369 http://sofifa.com/player/209852
# Brendan Galloway
# 370 http://sofifa.com/player/212158
# Osayamen Osawe
# 371 http://sofifa.com/player/182206
# Richard O
# 372 http://sofifa.com/player/201927
# Callum Harriott
# 373 http://sofifa.com/player/228295
# Rob Holding
# 374 http://sofifa.com/player/192970
# Danny Mayor
# 375 http://sofifa.com/player/179663
# Tommy Rowe
# 376 http://sofifa.com/player/184274
# Chris Basham
# 377 http://sofifa.com/player/139476
# Dean Gerken
# 378 http://sofifa.com/player/200667
# Max Power
# 379 http://sofifa.com/player/173531
# Ben Amos
# 380 http://sofifa.com/player/173533
# David Button
# 381 http://sofifa.com/player/176357
# John Mousinho
# 382 http://sofifa.com/player/111590
# Liam Feeney
# 383 http://sofifa.com/player/184300
# Jay Simpson
# 384 http://sofifa.com/player/53998
# Stephen Warnock
# 385 http://sofifa.com/player/173815
# Michael Bostwick
# 386 http://sofifa.com/player/222970
# Erhun Oztumer
# 387 http://sofifa.com/player/206075
# Sam Johnstone
# 388 http://sofifa.com/player/225024
# Mason Holgate
# 389 http://sofifa.com/player/163584
# Paul Robinson
# 390 http://sofifa.com/player/169474
# Andy Taylor
# 391 http://sofifa.com/player/190722
# Marvin Sordell
# 392 http://sofifa.com/player/193028
# Stuart Beavon
# 393 http://sofifa.com/player/186122
# Byron Webster
# 394 http://sofifa.com/player/200715
# Adam Davies
# 395 http://sofifa.com/player/212493
# Sullay Kaikai
# 396 http://sofifa.com/player/181521
# Sam Saunders
# 397 http://sofifa.com/player/202771
# Joe Newell
# 398 http://sofifa.com/player/169493
# Frank Fielding
# 399 http://sofifa.com/player/188181
# Dean Moxey
# 400 http://sofifa.com/player/163351
# Luke Varney
# 401 http://sofifa.com/player/178713
# Liam Trotter
# 402 http://sofifa.com/player/192540
# Mark Duffy
# 403 http://sofifa.com/player/200741
# Tyias Browning
# 404 http://sofifa.com/player/138279
# Lloyd Dyer
# 405 http://sofifa.com/player/178218
# Stephen Darby
# 406 http://sofifa.com/player/190254
# Wes Thomas
# 407 http://sofifa.com/player/202799
# Jordan Graham
# 408 http://sofifa.com/player/189492
# Stuart O
# 409 http://sofifa.com/player/195124
# David Amoo
# 410 http://sofifa.com/player/202808
# Nicholas Yennaris
# 411 http://sofifa.com/player/204860
# Kane Hemmings
# 412 http://sofifa.com/player/223551
# Lee Gregory
# 413 http://sofifa.com/player/202048
# Conor Coady
# 414 http://sofifa.com/player/164417
# James O
# 415 http://sofifa.com/player/200779
# Jonson Clarke
# 416 http://sofifa.com/player/173899
# Joe Skarz
# 417 http://sofifa.com/player/138830
# Dean Lewington
# 418 http://sofifa.com/player/204622
# Josh Meekings
# 419 http://sofifa.com/player/219216
# Josh Windass
# 420 http://sofifa.com/player/224081
# Kalvin Phillips
# 421 http://sofifa.com/player/205655
# Angus MacDonald
# 422 http://sofifa.com/player/177495
# Chris Taylor
# 423 http://sofifa.com/player/170078
# Mark Little
# 424 http://sofifa.com/player/173666
# Nicky Law
# 425 http://sofifa.com/player/200806
# Richard Smallwood
# 426 http://sofifa.com/player/170342
# Paul Huntington
# 427 http://sofifa.com/player/205161
# Harry Bunn
# 428 http://sofifa.com/player/53353
# Roger Johnson
# 429 http://sofifa.com/player/169578
# Calum Woods
# 430 http://sofifa.com/player/194925
# Louis Moult
# 431 http://sofifa.com/player/196976
# Nathan Cameron
# 432 http://sofifa.com/player/191090
# Tom Adeyemi
# 433 http://sofifa.com/player/118646
# Ian Henderson
# 434 http://sofifa.com/player/204412
# George Saville
# 435 http://sofifa.com/player/200319
# Ben Coker
# 436 http://sofifa.com/player/203138
# Josh Scowen
# 437 http://sofifa.com/player/169604
# Tommy Lee
# 438 http://sofifa.com/player/201093
# Nick Powell
# 439 http://sofifa.com/player/223877
# Darnell Furlong
# 440 http://sofifa.com/player/199815
# Sam Mantom
# 441 http://sofifa.com/player/221587
# Joe Lolley
# 442 http://sofifa.com/player/140442
# Andy Butler
# 443 http://sofifa.com/player/193187
# Kyle Bennett
# 444 http://sofifa.com/player/193956
# Ben Pringle
# 445 http://sofifa.com/player/216485
# Aaron Tshibola
# 446 http://sofifa.com/player/182694
# Joe Mattock
# 447 http://sofifa.com/player/208302
# Alex Gilbey
# 448 http://sofifa.com/player/221358
# Jordan Rossiter
# 449 http://sofifa.com/player/206518
# Callum Robinson
# 450 http://sofifa.com/player/201911
# Will Keane
# 451 http://sofifa.com/player/192695
# Nathan Thompson
# 452 http://sofifa.com/player/220862
# Jordan Hugill
# 453 http://sofifa.com/player/169919
# Paul Anderson
# 454 http://sofifa.com/player/201921
# Nicky Ajose
# 455 http://sofifa.com/player/51394
# Kevin Nolan
# 456 http://sofifa.com/player/213699
# Ashley Fletcher
# 457 http://sofifa.com/player/184515
# Nick Blackman
# 458 http://sofifa.com/player/202697
# Jack Stephens
# 459 http://sofifa.com/player/210635
# Kortney Hause
# 460 http://sofifa.com/player/216790
# Conor Grant
# 461 http://sofifa.com/player/156894
# Darren Pratley
# 462 http://sofifa.com/player/138719
# Chris O
# 463 http://sofifa.com/player/201446
# George Moncur
# 464 http://sofifa.com/player/201958
# Ethan Ebanks
# 465 http://sofifa.com/player/194792
# Luke Hyam
# 466 http://sofifa.com/player/206571
# Marcus Maddison
# 467 http://sofifa.com/player/203756
# Matt Smith
# 468 http://sofifa.com/player/203502
# Bobby Reid
# 469 http://sofifa.com/player/190451
# Nile Ranger
# 470 http://sofifa.com/player/194806
# Craig Dawson
# 471 http://sofifa.com/player/159490
# Paul Robinson
# 472 http://sofifa.com/player/155915
# Lewis Buxton
# 473 http://sofifa.com/player/163856
# Chris Dagnall
# 474 http://sofifa.com/player/164630
# David Raven
# 475 http://sofifa.com/player/229912
# Joshua Emmanuel
# 476 http://sofifa.com/player/170008
# Ben Hamer
# 477 http://sofifa.com/player/137498
# Brian Wilson
# 478 http://sofifa.com/player/190235
# Jordan Clarke
# 479 http://sofifa.com/player/211228
# Matthew Palmer
# 480 http://sofifa.com/player/2335
# Aaron Wilbraham
# 481 http://sofifa.com/player/163616
# Jamie Young
# 482 http://sofifa.com/player/208944
# Nathaniel Knight
# 483 http://sofifa.com/player/156464
# Richard Wood
# 484 http://sofifa.com/player/176442
# Robert Milsom
# 485 http://sofifa.com/player/202814
# Nathan Byrne
# 486 http://sofifa.com/player/204354
# Jak Alnwick
# 487 http://sofifa.com/player/212803
# Zach Clough
# 488 http://sofifa.com/player/173895
# Simon Eastwood
# 489 http://sofifa.com/player/188490
# Liam Sercombe
# 490 http://sofifa.com/player/205393
# Jack Baldwin
# 491 http://sofifa.com/player/182617
# Danny Hylton
# 492 http://sofifa.com/player/227675
# Marvin Johnson
# 493 http://sofifa.com/player/199516
# Ricky Holmes
# 494 http://sofifa.com/player/53855
# Nathan Tyson
# 495 http://sofifa.com/player/169571
# Danny Guthrie
# 496 http://sofifa.com/player/171620
# Anthony Wordsworth
# 497 http://sofifa.com/player/227686
# Keshi Anderson
# 498 http://sofifa.com/player/164465
# Tony McMahon
# 499 http://sofifa.com/player/225908
# Reece Oxford

# %% [markdown]
# #### 4. Use the *sklearn.cluster.KMeans* Python class to cluster the players into 5 clusters.

# %% [markdown]
# We first read the extracted and use the "head" function to inspect the first five rows.

# %%
#engPlayers = pd.read_csv('EnglishPlayers.csv')
argPlayers = pd.read_csv('ArgentinaPlayers.csv')
argPlayers.head()
# Out:
#                               link              name   position  Crossing  \
# 0  http://sofifa.com/player/158023     Lionel Messi          RW        77
# 1  http://sofifa.com/player/167664  Gonzalo Higuain          ST        68
# 2  http://sofifa.com/player/153079    Sergio Aguero          ST        70
# 3  http://sofifa.com/player/183898   Angel Di Maria   RW CM CAM        88
# 4  http://sofifa.com/player/211110     Paulo Dybala       ST CF        78
#
#    Finishing  Heading Accuracy  Short Passing  Volleys  Dribbling  Curve  \
# 0         95                71             88       85         97     89
# 1         92                80             73       88         84     69
# 2         90                68             79       85         89     82
# 3         74                53             83       77         87     83
# 4         89                65             80       86         91     86
#
#       ...       Penalties  Composure  Marking  Standing Tackle  \
# 0     ...              74         94       13               28
# 1     ...              70         84       12               22
# 2     ...              80         90       13               20
# 3     ...              73         80       37               59
# 4     ...              82         82       14               20
#
#    Sliding Tackle  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 0              26          6           11          15              14
# 1              18          5           12           7               5
# 2              12         13           15           6              11
# 3              56         10            7          11              12
# 4              20          5            4           4               5
#
#    GK Reflexes
# 0            8
# 1           10
# 2           14
# 3           11
# 4            8
#
# [5 rows x 37 columns]

# %% [markdown]
# As the first two columns of the data do not hold any useful information to cluster the data they will not be used.

# %%
# Number of clusters
numClusters = 5

#engAttrs = engPlayers.iloc[ : , 3: ].as_matrix() # Only use the attributes for clustering
argAttrs = argPlayers.iloc[ : , 3: ].as_matrix() # Only use the attributes for clustering
#kmeans = KMeans(init='k-means++', n_clusters = numClusters, n_init = 10, random_state = 99).fit(engAttrs)
kmeans = KMeans(init='k-means++', n_clusters = numClusters, n_init = 10, random_state = 99).fit(argAttrs)

# %% [markdown]
# We then attach the labels for each cluster to the original data.

# %%
# Q5

# From the five Excel files, we can see:
# See the following link for football positons, https://en.wikipedia.org/wiki/Association_football_positions
# For 500 English Players
# Cluster 0 = Wide Range of Defenders (Left-Backs, Centre-Backs, Right-Backs)
# Cluster 1 = Mainly Strikers and Attacking Midfielders
# Cluster 2 = Mainly Goalkeepers
# Cluster 3 = Mainly Defensive Midfielders
# Cluster 4 = Mainly Centre-Backs (Defenders)
# For 300 Argentina Players
# Cluster 0 = Mainly Strikers
# Cluster 1 = Mainly Centre-Backs (Defenders)
# Cluster 2 = All Goalkeepers
# Cluster 3 = Mainly Defenders (Left-Backs, Right-Backs) and Defensive Midfielders
# Cluster 4 = Mainly Attacking Midfielders and some strikers
for i in range(numClusters):
    #filename = 'EnglishCluster' + str(i) + '.csv'
    filename = 'ArgentinaCluster' + str(i) + '.csv'
    #engPlayers.iloc[kmeans.labels_ == i, 1:3].to_csv(filename)
    argPlayers.iloc[kmeans.labels_ == i, 1:3].to_csv(filename)

argPlayers['Cluster'] = kmeans.labels_

argPlayers.head()
# Out:
#                               link              name   position  Crossing  \
# 0  http://sofifa.com/player/158023     Lionel Messi          RW        77
# 1  http://sofifa.com/player/167664  Gonzalo Higuain          ST        68
# 2  http://sofifa.com/player/153079    Sergio Aguero          ST        70
# 3  http://sofifa.com/player/183898   Angel Di Maria   RW CM CAM        88
# 4  http://sofifa.com/player/211110     Paulo Dybala       ST CF        78
#
#    Finishing  Heading Accuracy  Short Passing  Volleys  Dribbling  Curve  \
# 0         95                71             88       85         97     89
# 1         92                80             73       88         84     69
# 2         90                68             79       85         89     82
# 3         74                53             83       77         87     83
# 4         89                65             80       86         91     86
#
#     ...     Composure  Marking  Standing Tackle  Sliding Tackle  GK Diving  \
# 0   ...            94       13               28              26          6
# 1   ...            84       12               22              18          5
# 2   ...            90       13               20              12         13
# 3   ...            80       37               59              56         10
# 4   ...            82       14               20              20          5
#
#    GK Handling  GK Kicking  GK Positioning  GK Reflexes  Cluster
# 0           11          15              14            8        4
# 1           12           7               5           10        2
# 2           15           6              11           14        4
# 3            7          11              12           11        4
# 4            4           4               5            8        4
#
# [5 rows x 38 columns]

# %% [markdown]
# * Cluster 0: Mix of Defenders and Defensive Midfielders
# * Cluster 1: Goalkeepers
# * Cluster 2: Mainly Strikers
# * Cluster 3: Mainly Centre-Backs
# * Cluster 4: Mainly Midfielders and Forward Players

# %% [markdown]
# As the data is high-dimensional, we plot the resulting clusters using the 7 attributes under question 6.

# %%
# assign names to clusters
argPlayers['Cluster Names'] = ['Defenders' if row == 0 else 
                  'Goalkeepers' if row == 1 else 
                  'Strikers' if row == 2 else
                  'Centre Backs' if row == 3 else
                  'Midfielders'
                  for row in argPlayers['Cluster']]

colPlot = ['Crossing', 'Sprint Speed', 'Long Shots', 'Aggression', 'Marking', 'Finishing', 'GK Handling'] + ['Cluster Names']

# sort data by Cluster
argPlayers = argPlayers.sort_values(['Cluster'], ascending= True)

plt.figure(figsize=(16,6))
parallel_coordinates(argPlayers.loc[ : , colPlot], 'Cluster Names', alpha = 0.7)

# %%
groupedData = argPlayers.groupby(argPlayers['Cluster Names']).mean()
groupedData['Cluster Names'] = groupedData.index

# sort data to have the same colors assigned to the same clusters as the previous plot
groupedData = groupedData.sort_values(['Cluster'], ascending= True)

plt.figure(figsize=(16,6))
parallel_coordinates(groupedData.loc[ : , colPlot], 'Cluster Names', linewidth=10, alpha = 0.9)

# %% [markdown]
# Plot the average of the twelve most important attributes for each cluster.

# %% [markdown]
# #### 6. For a new and unknown player, the following attributes are available:
#
# - Crossing: 45
# - Sprint Speed: 40
# - Long Shots: 35
# - Aggression: 45
# - Marking: 60
# - Finishing: 40
# - GK Handling: 15
#
# For each of your 5 clusters from Step 4, compute
# player to the nearest cluster based on the distance to the cluster centroids, using only the available attributes.

# %%
# Q6
newPlayerAttr = np.array([45, 40, 35, 45, 60, 40, 15]) # Attribute of new player

centroids = kmeans.cluster_centers_
#kmeans.fit(reduced_data)

# Indices of the available attributes
selectedAttrs = [attributes.index('Crossing'), attributes.index('Sprint Speed'), 
                 attributes.index('Long Shots'), attributes.index('Aggression'),
                 attributes.index('Marking'), attributes.index('Finishing'), attributes.index('GK Handling')]

# For each centroid, obtain only the values of selected attributes
centroidsSelected = centroids[ : , selectedAttrs]

# Calculate the distance to each of the 5 centroids, using only these selected attributes
distCentroids = np.linalg.norm(newPlayerAttr - centroidsSelected, axis = 1)

# (500 English Players) closest cluster = Cluster with index 4, centre-backs (defenders) cluster
# (300 Argentina Players) closest cluster = Cluster with index 1, centre-backs (defenders) cluster
np.argmin(distCentroids)
# Out:
# 3
